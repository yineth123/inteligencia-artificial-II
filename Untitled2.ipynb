# %% [markdown]
# <a href="https://colab.research.google.com/github/yineth123/inteligencia-artificial-II/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ML de extremo a extremo
#
# Fábrica de datos moderna: datos crudos → decisiones rentables.
#
# Visión general: definir meta → medir éxito → bajar datos.
#
# Exploración y visualización: revisar y entender datos crudos, como datos inmobiliarios.
#
# Preparación de datos: limpiar y organizar; convertir texto en números.
#
# Ingeniería de características: transformar los datos para obtener información útil.
#
# Selección y entrenamiento: elegir el algoritmo, por ejemplo, árboles de decisión.
#
# Sobreajuste: el modelo memoriza y falla con datos nuevos.
#
# Entrenamiento y validación: entrenar el modelo y comprobar su funcionamiento.
#
# Ajuste: búsqueda en cuadrícula para encontrar mejores parámetros.
#
# Evaluación: revisar los resultados del modelo.
#
# Lanzamiento: poner el modelo en funcionamiento.
#
# Reentrenamiento: si los datos siguen evolucionando, actualizar y reentrenar el modelo.
